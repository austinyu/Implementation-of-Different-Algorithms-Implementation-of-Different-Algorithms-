# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("experiment.csv")
df
# Out:
#       size    k   min   max   average
# 0         1   0     3     3         2
# 1         2   0     5     7         5
# 2         2   1     5     7         5
# 3         3   0     7    12         8
# 4         3   1     7    12         9
# ...     ...  ..   ...   ...       ...
# 1270     50  45   111   278       165
# 1271     50  46   101   280       163
# 1272     50  47   101   292       152
# 1273     50  48   101   260       149
# 1274     50  49   101   260       141
#
# [1275 rows x 5 columns]

# %%
size = df.iloc[:,0]
average = df.iloc[:, 4]

# %%
m, b = np.polyfit(size, average, 1, full = True)[0]
res = np.polyfit(size, average, 1, full = True)[4]
x = np.arange(size.min(), size.max(), .1)
plt.figure(figsize = (20, 10))
plt.plot(x, m * x + b, c = 'r')
plt.scatter(size, average, s = 5)
plt.suptitle('The Number of Swaps Operation vs Array Size')
plt.xlabel('Array Size')
plt.ylabel('The Number of Swaps Operation')
print(f'The sum of squared differences for linear approximation is {res}.')
# Out:
# The sum of squared differences for linear approximation is 2.831068712794149e-13.
