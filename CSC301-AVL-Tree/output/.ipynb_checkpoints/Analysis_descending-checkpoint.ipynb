# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
balance = pd.read_csv('balanced_descending.csv', header = None, index_col = 0).T
print('Statistics Summary for the Height of Balaced Trees from Ascending Keys')
balance = balance.iloc[:999, :]
balance = balance.astype('int64')
balance.describe(include = 'all')
# Out:
# Statistics Summary for the Height of Balaced Trees from Ascending Keys
# 0            64          128         256         512         1024        2048  \
# count  999.000000  999.000000  999.000000  999.000000  999.000000  999.000000
# mean     7.045045    8.258258    9.698699   10.942943   12.000000   13.038038
# std      0.207507    0.437896    0.459053    0.232068    0.044766    0.191384
# min      7.000000    8.000000    9.000000   10.000000   11.000000   13.000000
# 25%      7.000000    8.000000    9.000000   11.000000   12.000000   13.000000
# 50%      7.000000    8.000000   10.000000   11.000000   12.000000   13.000000
# 75%      7.000000    9.000000   10.000000   11.000000   12.000000   13.000000
# max      8.000000    9.000000   10.000000   11.000000   13.000000   14.000000
#
# 0            4096
# count  999.000000
# mean    14.279279
# std      0.448870
# min     14.000000
# 25%     14.000000
# 50%     14.000000
# 75%     15.000000
# max     15.000000

# %%
random = pd.read_csv('random_descending.csv', header = None, index_col = 0).T
print('Statistics Summary for the Height of Random Trees from Ascending Keys')
random = random.iloc[:999, :]
random = random.astype('int64')
random.describe()
# Out:
# Statistics Summary for the Height of Random Trees from Ascending Keys
# 0            64          128         256         512         1024        2048  \
# count  999.000000  999.000000  999.000000  999.000000  999.000000  999.000000
# mean    11.616617   14.050050   16.720721   19.542543   22.149149   24.835836
# std      1.433273    1.596432    1.689613    1.917628    1.943794    1.978612
# min      8.000000   10.000000   13.000000   15.000000   17.000000   20.000000
# 25%     11.000000   13.000000   16.000000   18.000000   21.000000   23.000000
# 50%     11.000000   14.000000   17.000000   19.000000   22.000000   25.000000
# 75%     12.000000   15.000000   18.000000   21.000000   23.000000   26.000000
# max     18.000000   21.000000   23.000000   26.000000   29.000000   33.000000
#
# 0            4096
# count  999.000000
# mean    27.570571
# std      2.002197
# min     23.000000
# 25%     26.000000
# 50%     27.000000
# 75%     29.000000
# max     35.000000

# %%
random_stacked = pd.DataFrame(random.stack())
size = [i[1] for i in np.array(random_stacked.index)]
height = [i[0] for i in random_stacked.values]
random_stacked = pd.DataFrame({'size' : size,
             'height' : height})
random_stacked['source'] = 'random'
random_stacked = random_stacked.sort_values('size')

# %%
balance_stacked = pd.DataFrame(balance.stack())
size = [i[1] for i in np.array(balance_stacked.index)]
height = [i[0] for i in balance_stacked.values]
balance_stacked = pd.DataFrame({'size' : size,
             'height' : height})
balance_stacked['source'] = 'balance'
balance_stacked = balance_stacked.sort_values('size')

# %%
merged = pd.merge(balance_stacked, random_stacked, how="outer")

# %%
plt.figure(figsize = (20, 10))
sns.violinplot(x="size", y="height", hue="source",
                    data=merged, split=True, scale = 'width')
plt.title('Comparison of Distribution the Height of Balanced and Unbalanced(random) BSTs from Descending Keys', fontsize = 20)
plt.xlabel('Tree Size', fontsize = 15)
plt.ylabel('Tree Height', fontsize = 15)
# Out:
# Text(0, 0.5, 'Tree Height')

# %%
plt.figure(figsize = (20, 10))
sns.violinplot(x="size", y="height",
                    data=random_stacked, scale = 'area')
plt.title('Distribution the Height of Unbalanced(random) BSTs from Descending Keys', fontsize = 20)
plt.xlabel('Tree Size', fontsize = 15)
plt.ylabel('Tree Height', fontsize = 15)
# Out:
# Text(0, 0.5, 'Tree Height')

# %%
plt.figure(figsize = (20, 10))
sns.violinplot(x="size", y="height",
                    data=balance_stacked, scale = 'count')
plt.title('Distribution the Height of Balanced BSTs from Descending Keys', fontsize = 20)
plt.xlabel('Tree Size', fontsize = 15)
plt.ylabel('Tree Height', fontsize = 15)
# Out:
# Text(0, 0.5, 'Tree Height')
